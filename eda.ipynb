# %%
import pandas as pd

# %%
df = pd.read_parquet("outputs/job_skill_lightcast_matches.parquet")

# %%
df[["post_id", "extracted_skill", "selected_lightcast_name", "selected_lightcast_subcategory_name", "selected_lightcast_category_name"]].to_csv("outputs/extracted_skills.csv")
